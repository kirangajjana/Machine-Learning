# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/placement.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
data.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %% [markdown]
# Steps followed for solving this problem
# machine learning development life cycle
# 1.Understanding the problem Formulation
#
# 2.Data collection
#
# 3.Preprocessing
#
# 4.Feature Engineering
#
# 5.Model selection
#
# 6.Model Training
#
# 7.Model Evaluation
#
# 8.Optimization
#
# 9.Model Deployment

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
data1=data.iloc[:, 1:]

# %%
data1
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['cgpa'],data['iq'],c=data['placement'])

# %%
x=data1.iloc[:, 0:2]
y=data1.iloc[:, -1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 23   4.7   87.0
# 69   8.5  120.0
# 72   7.3  116.0
# 51   4.8  141.0
# 53   8.3  168.0
# ..   ...    ...
# 73   4.9   61.0
# 22   4.9  120.0
# 84   5.7  169.0
# 46   5.3  114.0
# 49   5.4  135.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 23    0
# 69    1
# 72    1
# 51    0
# 53    1
#      ..
# 73    0
# 22    0
# 84    0
# 46    0
# 49    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 95   4.3  200.0
# 13   6.4  116.0
# 81   5.4  107.0
# 83   7.5  130.0
# 17   3.3  183.0
# 75   4.8  169.0
# 74   6.7  154.0
# 43   6.8  141.0
# 19   5.2  132.0
# 58   8.0   79.0

# %%
y_test
# Out:
# 95    0
# 13    1
# 81    0
# 83    1
# 17    0
# 75    0
# 74    1
# 43    1
# 19    0
# 58    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.18657815, -0.87030849],
#        [ 2.26125301, -0.04104439],
#        [ 1.17246422, -0.14156125],
#        [-1.09584575,  0.48666914],
#        [ 2.07978822,  1.16515796],
#        [-0.73291616,  2.57239402],
#        [-0.82364856,  1.36619168],
#        [-0.73291616, -0.79492085],
#        [-0.00705696,  0.68770286],
#        [-0.27925416,  0.2605062 ],
#        [ 0.90026703,  1.34106246],
#        [ 0.44660503,  0.96412423],
#        [-0.64218376, -0.01591517],
#        [ 0.71880223, -0.79492085],
#        [-0.91438096, -0.76979163],
#        [ 0.17440783, -0.21694889],
#        [-0.91438096, -0.09130282],
#        [ 0.90026703,  1.94416363],
#        [-0.73291616, -0.29233654],
#        [ 1.35392902,  0.9138658 ],
#        [ 1.17246422, -0.89543771],
#        [ 0.44660503, -0.79492085],
#        [-1.82170495, -0.54362869],
#        [ 0.44660503,  0.21024777],
#        [ 0.08367543,  0.2605062 ],
#        [ 1.62612622, -0.19181968],
#        [-1.18657815, -0.01591517],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-1.54950775,  1.96929285],
#        [ 0.35587263, -0.14156125],
#        [-0.55145136, -0.36772419],
#        [ 1.35392902,  0.21024777],
#        [-2.45683174,  1.54209619],
#        [-1.09584575,  1.19028717],
#        [ 0.62806983,  0.81334894],
#        [ 0.71880223,  0.48666914],
#        [-0.73291616,  0.2605062 ],
#        [ 1.80759102, -1.07134222]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
test=model.predict(x_test)

# %%
y_test
# Out:
# 95    0
# 13    1
# 81    0
# 83    1
# 17    0
# 75    0
# 74    1
# 43    1
# 19    0
# 58    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test,y_test)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values ,clf= model, zoom_factor= 10)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(model,open('LogisticRegressionmodel.pkl','wb'))
