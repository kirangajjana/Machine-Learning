# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/titanic.csv")

# %%
data
# Out:
#     Cabin            Ticket number  Survived
# 0     NaN         A/5 21171      5         0
# 1     C85          PC 17599      3         1
# 2     NaN  STON/O2. 3101282      6         1
# 3    C123            113803      3         1
# 4     NaN            373450      A         0
# ..    ...               ...    ...       ...
# 886   NaN            211536      3         0
# 887   B42            112053      3         1
# 888   NaN        W./C. 6607      1         0
# 889  C148            111369      2         1
# 890   NaN            370376      3         0
#
# [891 rows x 4 columns]

# %%
data['number'].unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
fig=data['number'].value_counts().plot.bar()

# %%
data['number_numberical']=pd.to_numeric(data['number'],errors='coerce',downcast='integer')

# %%
data
# Out:
#     Cabin            Ticket number  Survived  number_numberical
# 0     NaN         A/5 21171      5         0                5.0
# 1     C85          PC 17599      3         1                3.0
# 2     NaN  STON/O2. 3101282      6         1                6.0
# 3    C123            113803      3         1                3.0
# 4     NaN            373450      A         0                NaN
# ..    ...               ...    ...       ...                ...
# 886   NaN            211536      3         0                3.0
# 887   B42            112053      3         1                3.0
# 888   NaN        W./C. 6607      1         0                1.0
# 889  C148            111369      2         1                2.0
# 890   NaN            370376      3         0                3.0
#
# [891 rows x 5 columns]

# %%
data['number_categorical']=np.where(data['number_numberical'].isnull(),data['number'],np.nan)

# %%
data
# Out:
#     Cabin            Ticket number  Survived  number_numberical  \
# 0     NaN         A/5 21171      5         0                5.0
# 1     C85          PC 17599      3         1                3.0
# 2     NaN  STON/O2. 3101282      6         1                6.0
# 3    C123            113803      3         1                3.0
# 4     NaN            373450      A         0                NaN
# ..    ...               ...    ...       ...                ...
# 886   NaN            211536      3         0                3.0
# 887   B42            112053      3         1                3.0
# 888   NaN        W./C. 6607      1         0                1.0
# 889  C148            111369      2         1                2.0
# 890   NaN            370376      3         0                3.0
#
#     number_categorical
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                    A
# ..                 ...
# 886                NaN
# ...

# %%
data['number_numberical'].isnull().sum()
# Out:
# 139

# %%
from sklearn.impute import SimpleImputer

# %%
imputer=SimpleImputer()

# %%
z=data.iloc[:,4:5]

# %%
z
# Out:
#      number_numberical
# 0                  5.0
# 1                  3.0
# 2                  6.0
# 3                  3.0
# 4                  NaN
# ..                 ...
# 886                3.0
# 887                3.0
# 888                1.0
# 889                2.0
# 890                3.0
#
# [891 rows x 1 columns]

# %%
z1=imputer.fit_transform(z)

# %%
z1
# Out:
# array([[5.        ],
#        [3.        ],
#        [6.        ],
#        [3.        ],
#        [3.50664894],
#        [2.        ],
#        [2.        ],
#        [5.        ],
#        [1.        ],
#        [3.50664894],
#        [1.        ],
#        [1.        ],
#        [3.        ],
#        [3.        ],
#        [5.        ],
#        [3.        ],
#        [3.        ],
#        [2.        ],
#        [5.        ],
#        [4.        ],
#        [1.        ],
#        [4.        ],
#        [3.50664894],
#        [4.        ],
#        [5.        ],
#        [3.        ],
#        [6.        ],
#        [4.        ],
#        [2.        ],
#        [6.        ],
#        [2.        ],
#        [3.50664894],
#        [6.        ],
#        [2.        ],
#        [2.        ],
#        [2.        ],
#        [4.        ],
#        [6.        ],
#        [1.        ],
#        [6.        ],
#        [1.        ],
#        [3.        ],
#        [3.        ],
# ...

# %%
z
# Out:
#      number_numberical
# 0                  5.0
# 1                  3.0
# 2                  6.0
# 3                  3.0
# 4                  NaN
# ..                 ...
# 886                3.0
# 887                3.0
# 888                1.0
# 889                2.0
# 890                3.0
#
# [891 rows x 1 columns]

# %%
w=data.iloc[:,5:6]

# %%
w
# Out:
#     number_categorical
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                    A
# ..                 ...
# 886                NaN
# 887                NaN
# 888                NaN
# 889                NaN
# 890                NaN
#
# [891 rows x 1 columns]

# %%
w1=imputer.fit_transform(w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-55a6d0338ea5> in <cell line: 1>()
# ----> 1 w1=imputer.fit_transform(w)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
# ...

# %%
data['Cabin_num']=data['Cabin'].str.extract('(\d+)')#extract numerical values

# %%
data['Cabin_cat']=data['Cabin'].str[0]

# %%
data.head()
# Out:
#   Cabin            Ticket number  Survived  number_numberical  \
# 0   NaN         A/5 21171      5         0                5.0
# 1   C85          PC 17599      3         1                3.0
# 2   NaN  STON/O2. 3101282      6         1                6.0
# 3  C123            113803      3         1                3.0
# 4   NaN            373450      A         0                NaN
#
#   number_categorical Cabin_num Cabin_cat
# 0                NaN       NaN       NaN
# 1                NaN        85         C
# 2                NaN       NaN       NaN
# 3                NaN       123         C
# 4                  A       NaN       NaN

# %%
data
# Out:
#     Cabin            Ticket number  Survived  number_numberical  \
# 0     NaN         A/5 21171      5         0                5.0
# 1       8          PC 17599      3         1                3.0
# 2     NaN  STON/O2. 3101282      6         1                6.0
# 3       1            113803      3         1                3.0
# 4     NaN            373450      A         0                NaN
# ..    ...               ...    ...       ...                ...
# 886   NaN            211536      3         0                3.0
# 887     4            112053      3         1                3.0
# 888   NaN        W./C. 6607      1         0                1.0
# 889     1            111369      2         1                2.0
# 890   NaN            370376      3         0                3.0
#
#     number_categorical Cabin_num Cabin_cat cabin_num cabin_cat
# 0                  NaN       NaN       NaN       NaN       NaN
# 1                  NaN         8         8         8         8
# ...
